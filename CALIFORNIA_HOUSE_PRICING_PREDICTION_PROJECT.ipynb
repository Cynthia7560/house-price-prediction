# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv("housing.csv.zip")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
Unique_data=set(data)

# %%
Unique_data
# Out:
# {'households',
#  'housing_median_age',
#  'latitude',
#  'longitude',
#  'median_house_value',
#  'median_income',
#  'ocean_proximity',
#  'population',
#  'total_bedrooms',
#  'total_rooms'}

# %%
len(data)
# Out:
# 20640

# %%
len(Unique_data)
# Out:
# 10

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
data.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x=data.drop(["median_house_value"],axis=1)
y=data["median_house_value"]

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
train_data=x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18271    -122.09     37.36                37.0       1550.0           238.0
# 18724    -122.33     40.60                 5.0       6383.0          1206.0
# 11950    -117.44     33.94                30.0       2992.0           516.0
# 16128    -122.47     37.78                52.0       2388.0           507.0
# 4533     -118.22     34.03                45.0        554.0           214.0
# ...          ...       ...                 ...          ...             ...
# 12725    -121.35     38.61                27.0       3900.0           776.0
# 19392    -120.85     37.77                35.0        404.0            96.0
# 4944     -118.29     34.01                40.0        885.0           312.0
# 3709     -118.38     34.19                37.0       1434.0           394.0
# 16244    -121.28     37.99                42.0        495.0           116.0
#
#        population  households  median_income ocean_proximity  \
# 18271       805.0       250.0         5.0222        NEAR BAY
# 18724      2965.0      1141.0         3.8103          INLAND
# 11950      1521.0       507.0         3.9128          INLAND
# 16128      1078.0       494.0         3.5221        NEAR BAY
# 4533        888.0       218.0         1.8125       <1H OCEAN
# ...           ...         ...            ...             ...
# 12725      1549.0       761.0         2.7788          INLAND
# 19392       261.0       100.0         2.4583          INLAND
# 4944        799.0       221.0         1.1667       <1H OCEAN
# 3709       1667.0       404.0         2.4375       <1H OCEAN
# 16244       284.0        97.0         2.8854          INLAND
#
#        median_house_value
# 18271            500001.0
# 18724            111100.0
# 11950            126900.0
# 16128            443300.0
# 4533             139600.0
# ...                   ...
# 12725            115700.0
# 19392             75000.0
# 4944             143800.0
# 3709             176300.0
# 16244             55700.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(16,9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr()
# Out:
# <ipython-input-20-8d2cc80a8830>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_data.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924985           -0.108555     0.049846
# latitude            -0.924985  1.000000            0.013415    -0.040976
# housing_median_age  -0.108555  0.013415            1.000000    -0.364712
# total_rooms          0.049846 -0.040976           -0.364712     1.000000
# total_bedrooms       0.072218 -0.068967           -0.327337     0.931567
# population           0.101027 -0.109101           -0.299196     0.858788
# households           0.059659 -0.073778           -0.309114     0.920757
# median_income       -0.013128 -0.080477           -0.118207     0.196585
# median_house_value  -0.040174 -0.147882            0.101791     0.132890
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.072218    0.101027    0.059659      -0.013128
# latitude                 -0.068967   -0.109101   -0.073778      -0.080477
# housing_median_age       -0.327337   -0.299196   -0.309114      -0.118207
# total_rooms               0.931567    0.858788    0.920757       0.196585
# total_bedrooms            1.000000    0.877999    0.980601      -0.005836
# population                0.877999    1.000000    0.905862       0.007793
# households                0.980601    0.905862    1.000000       0.014714
# median_income            -0.005836    0.007793    0.014714       1.000000
# median_house_value        0.048633   -0.023076    0.063900       0.693416
#
#                     median_house_value
# longitude                    -0.040174
# latitude                     -0.147882
# housing_median_age            0.101791
# total_rooms                   0.132890
# total_bedrooms                0.048633
# population                   -0.023076
# households                    0.063900
# median_income                 0.693416
# median_house_value            1.000000

# %%
plt.figure(figsize=(16,9))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <ipython-input-21-4f2db287aeb2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# <Axes: >

# %%
train_data["total_rooms"]=np.log(train_data["total_rooms"]+1)
train_data["total_bedrooms"]=np.log(train_data["total_bedrooms"]+1)
train_data["population"]=np.log(train_data["population"]+1)
train_data["households"]=np.log(train_data["households"]+1)

# %%
train_data.hist(figsize=(16,9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     7196
# INLAND        5211
# NEAR OCEAN    2106
# NEAR BAY      1829
# ISLAND           4
# Name: ocean_proximity, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 18271          0       0       0         1           0
# 18724          0       1       0         0           0
# 11950          0       1       0         0           0
# 16128          0       0       0         1           0
# 4533           1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 12725          0       1       0         0           0
# 19392          0       1       0         0           0
# 4944           1       0       0         0           0
# 3709           1       0       0         0           0
# 16244          0       1       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data.join(pd.get_dummies(train_data.ocean_proximity))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18271    -122.09     37.36                37.0     7.346655        5.476464
# 18724    -122.33     40.60                 5.0     8.761550        7.095893
# 11950    -117.44     33.94                30.0     8.004032        6.248043
# 16128    -122.47     37.78                52.0     7.778630        6.230481
# 4533     -118.22     34.03                45.0     6.318968        5.370638
# ...          ...       ...                 ...          ...             ...
# 12725    -121.35     38.61                27.0     8.268988        6.655440
# 19392    -120.85     37.77                35.0     6.003887        4.574711
# 4944     -118.29     34.01                40.0     6.786717        5.746203
# 3709     -118.38     34.19                37.0     7.268920        5.978886
# 16244    -121.28     37.99                42.0     6.206576        4.762174
#
#        population  households  median_income ocean_proximity  \
# 18271    6.692084    5.525453         5.0222        NEAR BAY
# 18724    7.994970    7.040536         3.8103          INLAND
# 11950    7.327781    6.230481         3.9128          INLAND
# 16128    6.983790    6.204558         3.5221        NEAR BAY
# 4533     6.790097    5.389072         1.8125       <1H OCEAN
# ...           ...         ...            ...             ...
# 12725    7.346010    6.635947         2.7788          INLAND
# 19392    5.568345    4.615121         2.4583          INLAND
# 4944     6.684612    5.402677         1.1667       <1H OCEAN
# 3709     7.419381    6.003887         2.4375       <1H OCEAN
# 16244    5.652489    4.584967         2.8854          INLAND
#
#        median_house_value  <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 18271            500001.0          0       0       0         1           0
# 18724            111100.0          0       1       0         0           0
# 11950            126900.0          0       1       0         0           0
# 16128            443300.0          0       0       0         1           0
# 4533             139600.0          1       0       0         0           0
# ...                   ...        ...     ...     ...       ...         ...
# 12725            115700.0          0       1       0         0           0
# 19392             75000.0          0       1       0         0           0
# 4944             143800.0          1       0       0         0           0
# 3709             176300.0          1       0       0         0           0
# 16244             55700.0          0       1       0         0           0
#
# [16346 rows x 15 columns]

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(["ocean_proximity"],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18271    -122.09     37.36                37.0     7.346655        5.476464
# 18724    -122.33     40.60                 5.0     8.761550        7.095893
# 11950    -117.44     33.94                30.0     8.004032        6.248043
# 16128    -122.47     37.78                52.0     7.778630        6.230481
# 4533     -118.22     34.03                45.0     6.318968        5.370638
# ...          ...       ...                 ...          ...             ...
# 12725    -121.35     38.61                27.0     8.268988        6.655440
# 19392    -120.85     37.77                35.0     6.003887        4.574711
# 4944     -118.29     34.01                40.0     6.786717        5.746203
# 3709     -118.38     34.19                37.0     7.268920        5.978886
# 16244    -121.28     37.99                42.0     6.206576        4.762174
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 18271    6.692084    5.525453         5.0222            500001.0          0
# 18724    7.994970    7.040536         3.8103            111100.0          0
# 11950    7.327781    6.230481         3.9128            126900.0          0
# 16128    6.983790    6.204558         3.5221            443300.0          0
# 4533     6.790097    5.389072         1.8125            139600.0          1
# ...           ...         ...            ...                 ...        ...
# 12725    7.346010    6.635947         2.7788            115700.0          0
# 19392    5.568345    4.615121         2.4583             75000.0          0
# 4944     6.684612    5.402677         1.1667            143800.0          1
# 3709     7.419381    6.003887         2.4375            176300.0          1
# 16244    5.652489    4.584967         2.8854             55700.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 18271       0       0         1           0
# 18724       1       0         0           0
# 11950       1       0         0           0
# 16128       0       0         1           0
# 4533        0       0         0           0
# ...       ...     ...       ...         ...
# 12725       1       0         0           0
# 19392       1       0         0           0
# 4944        0       0         0           0
# 3709        0       0         0           0
# 16244       1       0         0           0
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(16,9))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"]=train_data["total_bedrooms"]/train_data["total_rooms"]
train_data["household_rooms"]=train_data["total_rooms"]/train_data["households"]

# %%
plt.figure(figsize=(16,9))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression


x_train,y_train=train_data.drop(["median_house_value"],axis=1),train_data["median_house_value"]

reg=LinearRegression()
reg.fit(x_train,y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
test_data=x_test.join(y_test)
test_data["total_rooms"]=np.log(test_data["total_rooms"]+1)
test_data["total_bedrooms"]=np.log(test_data["total_bedrooms"]+1)
test_data["population"]=np.log(test_data["population"]+1)
test_data["households"]=np.log(test_data["households"]+1)


test_data["bedroom_ratio"]=test_data["total_bedrooms"]/test_data["total_rooms"]
test_data["household_rooms"]=test_data["total_rooms"]/test_data["households"]

# %%
x_test,y_test=test_data.drop(["median_house_value"],axis=1),test_data["median_house_value"]

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8377     -118.35     33.95                30.0     7.886833        6.641182
# 6276     -117.93     34.01                33.0     7.458186        5.891644
# 9287     -122.55     38.07                38.0     8.129470        6.565265
# 11396    -117.97     33.73                19.0     8.332068        6.329721
# 2981     -119.02     35.33                26.0     8.213924        6.717805
# ...          ...       ...                 ...          ...             ...
# 8006     -118.10     33.85                36.0     6.863803        5.075174
# 18963    -122.04     38.27                16.0     9.049937        7.555382
# 10143    -117.90     33.90                19.0     7.685703        6.028279
# 1442     -122.00     37.99                28.0     8.303009        6.464588
# 3359     -120.64     40.41                50.0     7.462789        6.052089
#
#        population  households  median_income ocean_proximity  \
# 8377     7.751475    6.586172         3.0519       <1H OCEAN
# 6276     7.471932    5.929589         4.2266       <1H OCEAN
# 9287     7.546974    6.570883         3.0573        NEAR BAY
# 11396    7.664347    6.380123         7.2845       <1H OCEAN
# 2981     7.636752    6.719013         2.1553          INLAND
# ...           ...         ...            ...             ...
# 8006     6.033086    5.062595         4.6429       <1H OCEAN
# 18963    8.413831    7.516433         3.1853          INLAND
# 10143    6.910751    5.998937         4.9743       <1H OCEAN
# 1442     7.540090    6.492240         5.4607          INLAND
# 3359     6.895683    5.950643         1.5066          INLAND
#
#        median_house_value  bedroom_ratio  household_rooms
# 8377             137500.0       0.842059         1.197484
# 6276             153800.0       0.789957         1.257791
# 9287             350800.0       0.807588         1.237196
# 11396            301800.0       0.759682         1.305942
# 2981              84700.0       0.817856         1.222490
# ...                   ...            ...              ...
# 8006             223700.0       0.739411         1.355788
# 18963            129600.0       0.834855         1.204020
# 10143            193500.0       0.784350         1.281178
# 1442             192300.0       0.778584         1.278913
# 3359              59300.0       0.810969         1.254115
#
# [4087 rows x 12 columns]

# %%
y_test
# Out:
# 8377     137500.0
# 6276     153800.0
# 9287     350800.0
# 11396    301800.0
# 2981      84700.0
#            ...
# 8006     223700.0
# 18963    129600.0
# 10143    193500.0
# 1442     192300.0
# 3359      59300.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8377     -118.35     33.95                30.0     7.886833        6.641182
# 6276     -117.93     34.01                33.0     7.458186        5.891644
# 9287     -122.55     38.07                38.0     8.129470        6.565265
# 11396    -117.97     33.73                19.0     8.332068        6.329721
# 2981     -119.02     35.33                26.0     8.213924        6.717805
# ...          ...       ...                 ...          ...             ...
# 8006     -118.10     33.85                36.0     6.863803        5.075174
# 18963    -122.04     38.27                16.0     9.049937        7.555382
# 10143    -117.90     33.90                19.0     7.685703        6.028279
# 1442     -122.00     37.99                28.0     8.303009        6.464588
# 3359     -120.64     40.41                50.0     7.462789        6.052089
#
#        population  households  median_income ocean_proximity  bedroom_ratio  \
# 8377     7.751475    6.586172         3.0519       <1H OCEAN       0.842059
# 6276     7.471932    5.929589         4.2266       <1H OCEAN       0.789957
# 9287     7.546974    6.570883         3.0573        NEAR BAY       0.807588
# 11396    7.664347    6.380123         7.2845       <1H OCEAN       0.759682
# 2981     7.636752    6.719013         2.1553          INLAND       0.817856
# ...           ...         ...            ...             ...            ...
# 8006     6.033086    5.062595         4.6429       <1H OCEAN       0.739411
# 18963    8.413831    7.516433         3.1853          INLAND       0.834855
# 10143    6.910751    5.998937         4.9743       <1H OCEAN       0.784350
# 1442     7.540090    6.492240         5.4607          INLAND       0.778584
# 3359     6.895683    5.950643         1.5066          INLAND       0.810969
#
#        household_rooms
# 8377          1.197484
# 6276          1.257791
# 9287          1.237196
# 11396         1.305942
# 2981          1.222490
# ...                ...
# 8006          1.355788
# 18963         1.204020
# 10143         1.281178
# 1442          1.278913
# 3359          1.254115
#
# [4087 rows x 11 columns]

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18271    -122.09     37.36                37.0     7.346655        5.476464
# 18724    -122.33     40.60                 5.0     8.761550        7.095893
# 11950    -117.44     33.94                30.0     8.004032        6.248043
# 16128    -122.47     37.78                52.0     7.778630        6.230481
# 4533     -118.22     34.03                45.0     6.318968        5.370638
# ...          ...       ...                 ...          ...             ...
# 12725    -121.35     38.61                27.0     8.268988        6.655440
# 19392    -120.85     37.77                35.0     6.003887        4.574711
# 4944     -118.29     34.01                40.0     6.786717        5.746203
# 3709     -118.38     34.19                37.0     7.268920        5.978886
# 16244    -121.28     37.99                42.0     6.206576        4.762174
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 18271    6.692084    5.525453         5.0222          0       0       0
# 18724    7.994970    7.040536         3.8103          0       1       0
# 11950    7.327781    6.230481         3.9128          0       1       0
# 16128    6.983790    6.204558         3.5221          0       0       0
# 4533     6.790097    5.389072         1.8125          1       0       0
# ...           ...         ...            ...        ...     ...     ...
# 12725    7.346010    6.635947         2.7788          0       1       0
# 19392    5.568345    4.615121         2.4583          0       1       0
# 4944     6.684612    5.402677         1.1667          1       0       0
# 3709     7.419381    6.003887         2.4375          1       0       0
# 16244    5.652489    4.584967         2.8854          0       1       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 18271         1           0       0.745436         1.329602
# 18724         0           0       0.809890         1.244444
# 11950         0           0       0.780612         1.284657
# 16128         1           0       0.800974         1.253696
# 4533          0           0       0.849923         1.172552
# ...         ...         ...            ...              ...
# 12725         0           0       0.804868         1.246090
# 19392         0           0       0.761958         1.300917
# 4944          0           0       0.846684         1.256177
# 3709          0           0       0.822527         1.210702
# 16244         0           0       0.767279         1.353679
#
# [16346 rows x 15 columns]

# %%
y_train
# Out:
# 18271    500001.0
# 18724    111100.0
# 11950    126900.0
# 16128    443300.0
# 4533     139600.0
#            ...
# 12725    115700.0
# 19392     75000.0
# 4944     143800.0
# 3709     176300.0
# 16244     55700.0
# Name: median_house_value, Length: 16346, dtype: float64

# %%
reg.score(x_train,y_train)
# Out:
# 0.674901906726037

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_train,y_train)
# Out:
# 0.9746610301941195

# %%
from sklearn.model_selection import GridSearchCV
forest=RandomForestRegressor()
param_grid={
    "n_estimators":[2,10,20],
    "max_features":[1,3,5,7]
 }
grid_search= GridSearchCV(forest, param_grid, cv= 4, scoring="neg_mean_squared_error", return_train_score=True)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [1, 3, 5, 7],
#                          'n_estimators': [2, 10, 20]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=7, n_estimators=20)

# %%
best_forest=grid_search.best_estimator_

# %%
best_forest.score(x_train,y_train)
# Out:
# 0.9688911972746963
